# %% [markdown]
# ## Taller 3 Cinepython
#
# ### Diplomado Python aplicado a la ingeniería
#
#
# #### Wendy Mendoza Barrera
# - ID: 502216
# - Email:wendy.mendozab@upb.edu.co
#
#
# #### Angela Posso Diaz
# - ID: 502224
# - Email:angela.posso@upb.edu.co
#
#
# #### Adriana Suarez Ballesteros
# - ID: 502197
# - email: adriana.suarezb@upb.edu.co
#
#
# Para el ejercicio:

# %%
from io import open
nueva=[] # lista donde se va guardar los datos de una reservacion
listaPeliculas=[["Los croods 2", 54000, "Pelicula"], ["Tom y Jerry", 12000, "Pelicula"],["A la fuga", 47000, "Pelicula"], ["Instinto peligroso",4700, "Pelicula"], ["Rambo", 1400, "Pelicula"], ["Shuek",54000, "Pelicula"],["Juego del calamar", 14000, "Serie"], ["La casa de papel", 20000, "Serie"],["Palpito",14700, "Serie"], ["La jauria", 4100, "Serie"], ["Vikingos",14000, "Serie"]]
diccionarioComida={1:["Combo Croissant Huevo Y Tocineta Con Hashbrown", "tu Combo viene acompañado de Croissant Relleno de huevos revueltos y tocineta con Hashbrown y Café 12oz", 10000, "McDonals"],
             2:["Combo Pancakes con Hashbrown", "Tu Combo viene acompañado de tres pancakes con salsa syrup y Café 12oz", 9000, "McDonals"],
             3:["1 Cajita Feliz de Nuggets", "1 Cajita Feliz de Nuggets +1 McCombo de Hamburguesa McNifica con Coca-Cola sin azúcar 1.75 ", 14000, "McDonals"],
             4:["Vaquero Callejero en combo","perro caliente con salchicha de 125 g a la parrilla, papa callejera, cebolla picada y salsas en pan perro + papas medianas (Corral o cascos) + bebida PET", 12000, "McDonals"],
             5:["Pollo Cebollitas Crunchy en combo", "Hamburguesa de 154 g de pechuga de pollo en salsa BBQ, con cebolla crujiente, lechuga en julianas, salsa BBQ y salsa miel mostaza en pan ajonjolí + papas medianas (Corral o cascos) + bebida PET", 12000, "McDonals"],
             6:["Pollo 1", "Pollo 1 Cebollitas Crunchy en combo", 10000,"El Corral"],
             7:["Pollo 2", "Pollo 2 Cebollitas Crunchy en combo", 11000,"El Corral"],
             8:["Pollo 3", "Pollo 3 Cebollitas Crunchy en combo", 13000,"El Corral"],
             9:["Pollo 4", "Pollo 4 Cebollitas Crunchy en combo", 14000, "El Corral"],
             10:["Pollo 5", "Pollo 5 Cebollitas Crunchy en combo", 12000, "El Corral"],
             11:["COMBO 1", "palomitas de maiz + gaseosa + perro caliente", 10000,"CinePython"],
             12:["COMBO 2", "palomitas de maiz + gaseosa + perro caliente", 15000,"CinePython"],
             13:["COMBO 3", "palomitas de maiz + gaseosa + perro caliente", 11000,"CinePython"],
             14:["COMBO 4", "palomitas de maiz + gaseosa + perro caliente", 14000,"CinePython"],
             15:["COMBO 5", "palomitas de maiz + gaseosa + perro caliente", 13000,"CinePython"]}

def funcionPdf(aux, nombre):
    archivo=open(f"{nombre}.txt","w")
    archivo.write(aux)
    archivo.close()

# funcion para seleccionar una pelicula
def peliculas(lista):
    opcion =0
    pelicula=""
    while opcion==0:
        print("\tPeliculas Disponibles")
        print("1. Los croods 2\n2. Tom y Jerry\n3. A la fuga\n4. Instinto peligroso\n5. Rambo")
        opcion = int(input("Seleccione una Pelicula : "))
        if opcion==1:
            pelicula=lista[0]
        elif opcion ==2:
            pelicula=lista[1]
        elif opcion ==3:
            pelicula=lista[2]
        elif opcion ==4:
            pelicula=lista[3]
        elif opcion ==5:
            pelicula=lista[4]
        else:
            print("Opcion No valida\n\n")
            opcion=0
    return pelicula
            
# funcion para seleccionar una serie
def series(lista):
    opcion =0
    serie=""
    while opcion==0:
        print("\tSeries Disponibles")
        print("1. Juego del calamar 2\n2. La casa de papel\n3. Palpito\n4. La jauria\n5. Vikingos")
        opcion = int(input("Seleccione una Serie : "))
        if opcion==1:
             serie=lista[5]
        elif opcion ==2:
             serie=lista[6]
        elif opcion ==3:
             serie=lista[7]
        elif opcion ==4:
             serie=lista[8]
        elif opcion ==5:
             serie=lista[9]
        else:
            print("Opcion No valida\n\n")
            opcion=0
    return serie

# funcion para seleccionar una comida
def comidasMAcdonal(lista):
    opcion =True
    pos=""
    while opcion==True:
        print("\tMenu Macdonals")
        print("1. Combo Croissant Huevo Y Tocineta Con Hashbrown 2")
        print("2. Combo Pancakes con Hashbrown")
        print("3. 1 Cajita Feliz de Nuggets")
        print("4. Vaquero Callejero en combo")
        print("5. Pollo Cebollitas Crunchy en combo\n")
        print("")
        opcion = int(input("Seleccione una opcion : "))
        if opcion==1:
            pos=lista[1]
            opcion=False
        elif opcion ==2:
            pos=lista[2]
            opcion=False
        elif opcion ==3:
            pos=lista[3]
            opcion=False
        elif opcion ==4:
            pos=lista[4]
            opcion=False
        elif opcion ==5:
            pos=lista[5]
            opcion=False
        else:
            print("Opcion No valida\n\n")
            opcion=True
    return pos

def comidasCorral(lista):
    opcion =True
    pos=""
    while opcion==True:
        print("\tMenu Corral")
        print("1. (combo) Pollo 1 Cebollitas Crunchy en combo $10.000")
        print("2. (combo) Pollo 2 Cebollitas Crunchy en combo $11.000")
        print("3. (combo) Pollo 3 Cebollitas Crunchy en combo $13.000")
        print("4. (combo) Pollo 4 Cebollitas Crunchy en combo $14.000")
        print("5. (combo) Pollo 5 Cebollitas Crunchy en combo $12.000\n")
        print("")
        opcion = int(input("Seleccione un combo : "))
        if opcion==1:
            pos=lista[6]
            opcion=False
        elif opcion ==2:
            pos=lista[7]  
            opcion=False
        elif opcion ==3:
            pos=lista[8]      
            opcion=False
        elif opcion ==4:
            pos=lista[9]   
            opcion=False
        elif opcion ==5:
            pos=lista[10]
            opcion=False
        else:
            print("Opcion No valida\n\n")
            opcion=True
    return pos

def comidasCinepython(lista):
    opcion=True
    pos=0
    while opcion==True:
        print("\tMenu Cine-Python")
        print("1. COMBO 1 palomitas de maiz + gaseosa + perro caliente precio $10.000")
        print("2. COMBO 2 palomitas de maiz + gaseosa + perro caliente precio $15.000")
        print("3. COMBO 3 palomitas de maiz + gaseosa + perro caliente precio $11.000")
        print("4. COMBO 4 palomitas de maiz + gaseosa + perro caliente precio $14.000")
        print("5. COMBO 5 palomitas de maiz + gaseosa + perro caliente precio $13.000\n")
        print("")
        opcion = int(input("Seleccione una opcion : "))
        if opcion==1:
            pos=lista[11]
            opcion=False
        elif opcion ==2:
            pos=lista[12]
            opcion=False
        elif opcion ==3:
            pos=lista[13]
            opcion=False
        elif opcion ==4:
            pos=lista[14]
            opcion=False
        elif opcion ==5:
            pos=lista[15]
            opcion=False
        else:
            print("Opcion No valida\n\n")
            opcion=True
    return pos

# funcion para calular el total
def calcularTotal(costoPelicula, costoRestaurante, cantidad):
    return costoPelicula+(costoRestaurante*cantidad)

def llenar(nueva):
    # variables y asignacion
    nombre=input("Ingrese el nombre del cliente: ")
    ver=""
    restaurante=""
    opcion=True

    #ingreso de datos utilizando las funciones
    # seleccionar una pelicula
    while opcion==True:
        op=int(input("¿Qué desea ver? \n1. PeliculaS\n2. Series\n seleccione: "))
        if op==1:
            ver=peliculas(listaPeliculas)
            opcion=False
        elif op==2:
            ver=series(listaPeliculas)
            opcion=False
        else:
            print("La opcion NO es valida\n")

    # seleccionar  la cantidad
    opcion=True
    while opcion==True:
        espacio=int(input("Ingrese la cantidad de personas del grupo (Cupo minimo = 10) "))
        if espacio >10:
            opcion=False
        else:
            print("La cantidad de personas debe ser mayor a  10")

    # seleccionar un restaurante con su combo
    opcion=True
    while opcion==True:
        print("\nSeleccion Restaurante Favorito\n1. McDonals\n2. El Corral\n3. Cine-Python")
        comida= int(input("Ingrese una opcion: "))
        if comida ==1:
            restaurante=comidasMAcdonal(diccionarioComida)
            opcion=False
        elif comida ==2:
            restaurante=comidasCorral(diccionarioComida)
            opcion=False
        elif comida==3:
            restaurante=comidasCinepython(diccionarioComida)
            opcion=False
        else:
            print("Seleccione una opcion valida")
    # lista auxiliar para guardar los datos en una nueva reservacion
    lista=[nombre,  ver, espacio, restaurante]
    # lista que guarda los datos de la reservacion
    nueva.append(lista)

# Mostrar datos
def mostrar(nueva):
    total=calcularTotal(nueva[0][1][1],nueva[0][3][2], nueva[0][2] )
    aux=f"--------- Factura de Cine-Python 2022 ----------- \n\n"
    aux+=f"Nombre del cliente: {nueva[0][0]}\n"
    aux+=f"\nTipo de {nueva[0][1][2]}\n"
    aux+=f"Pelicula es: {nueva[0][1][0]}\n"
    aux+=f"Valor de La pelicula: {nueva[0][1][1]}\n"
    aux+=f"Cantidad de Personas: {nueva[0][2]}\n\n"
    aux+="\t-------Datos de Combo----------\n"
    aux+=f"Restaurante {nueva[0][3][3]}\n"
    aux+=f"Nombre del combo: {nueva[0][3][0]}\n"
    aux+=f"Descripcion Combo: {nueva[0][3][1]}\n"
    aux+=f"valor unitario de un combo: {nueva[0][3][2]}\n"
    aux+=f"cantidad de Compras:  {nueva[0][2]}\n"
    aux+=f"total a Pagar: {total}\n"
     
    # crear el archivo con la factura
    funcionPdf(aux, nueva[0][0])
    print(aux)
    nueva=[]
   
 # menu principal
menu=1
while menu==1:
    opcion = int(input("Menu Principal Bienvenido a CinePython\n1. Reservar y Alquiler\n2. Imprimir factura\n3. salir\nSeleccione una opcion:  "))
    if opcion==1:
        llenar(nueva)
    elif opcion==2:
        mostrar(nueva)
    elif opcion==3:
        print("Acaba de salir exitosamente , vuelva pronto")
        menu=0
    else:
        print("Seleccione una opcion valida")
# Out:
# Menu Principal Bienvenido a CinePython
# 1. Reservar y Alquiler
# 2. Imprimir factura
# 3. salir
# Seleccione una opcion:  1
# Ingrese el nombre del cliente: lina
# ¿Qué desea ver?
# 1. PeliculaS
# 2. Series
#  seleccione: 1
# 	Peliculas Disponibles
# 1. Los croods 2
# 2. Tom y Jerry
# 3. A la fuga
# 4. Instinto peligroso
# 5. Rambo
# Seleccione una Pelicula : 2
# Ingrese la cantidad de personas del grupo (Cupo minimo = 10) 12
#
# Seleccion Restaurante Favorito
# 1. McDonals
# 2. El Corral
# 3. Cine-Python
# Ingrese una opcion: 1
# 	Menu Macdonals
# 1. Combo Croissant Huevo Y Tocineta Con Hashbrown 2
# 2. Combo Pancakes con Hashbrown
# 3. 1 Cajita Feliz de Nuggets
# 4. Vaquero Callejero en combo
# 5. Pollo Cebollitas Crunchy en combo
#
#
# Seleccione una opcion : 2
# Menu Principal Bienvenido a CinePython
# 1. Reservar y Alquiler
# 2. Imprimir factura
# 3. salir
# Seleccione una opcion:  2
# --------- Factura de Cine-Python 2022 -----------
#
# Nombre del cliente: lina
#
# ...
